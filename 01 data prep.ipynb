# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score

# %% [markdown]
# ### 1. importing dataset
# * removed observations where IsBadBuy is missing

# %%
df = pd.read_csv('kickcars-sample-200.csv')
df = df[df['IsBadBuy'].notnull()]
df.shape
# Out:
# (195, 34)

# %% [markdown]
# ### 2. removing columns
# * dropped PurchDate and VehYear as we already have VehicleAge
# * dropped TopThreeAmericanName as as we already have Make
# * dropped WheelTypeID as we already have WheelType
# * dropped VNZIP1 as we already have VNST
# * dropped Model and SubModel as there are multiple values
# * dropped Trim as there are multiple values
# * dropped Auction and IsOnlineSale as there are single values
# * dropped Color and BYRNO as these may be misleading
# * dropped AUCGUART as it is same as PRIMEUNIT

# %%
df = df.drop(['PurchDate','VehYear','WheelTypeID','TopThreeAmericanName','VNZIP1'], axis=1)
df = df.drop(['Model','SubModel','Trim'], axis=1)
df = df.drop(['Auction','IsOnlineSale','Color','BYRNO','AUCGUART'], axis=1)
df.shape
# Out:
# (195, 21)

# %% [markdown]
# ### 3. creating columns - numerical
# * ratio of acquisition cost paid for the vehicle at time of purchase is taken
# * if ratio is less than or equal to zero then it is made missing
# * missing value is also imputed
# * all positively related

# %%
df['MMRAcquisitionAuctionAveragePrice'] = df['VehBCost'] / df['MMRAcquisitionAuctionAveragePrice']
df['MMRAcquisitionAuctionCleanPrice'] = df['VehBCost'] / df['MMRAcquisitionAuctionCleanPrice']
df['MMRAcquisitionRetailAveragePrice'] = df['VehBCost'] / df['MMRAcquisitionRetailAveragePrice']
df['MMRAcquisitonRetailCleanPrice'] = df['VehBCost'] / df['MMRAcquisitonRetailCleanPrice']
df['MMRCurrentAuctionAveragePrice'] = df['VehBCost'] / df['MMRCurrentAuctionAveragePrice']
df['MMRCurrentAuctionCleanPrice'] = df['VehBCost'] / df['MMRCurrentAuctionCleanPrice']
df['MMRCurrentRetailAveragePrice'] = df['VehBCost'] / df['MMRCurrentRetailAveragePrice']
df['MMRCurrentRetailCleanPrice'] = df['VehBCost'] / df['MMRCurrentRetailCleanPrice']
df['WarrantyCost'] = df['WarrantyCost'] / df['VehBCost']

df['MMRAcquisitionAuctionAveragePrice'] = np.where(df['MMRAcquisitionAuctionAveragePrice']==np.inf, np.nan, df['MMRAcquisitionAuctionAveragePrice'])
df['MMRAcquisitionAuctionCleanPrice'] = np.where(df['MMRAcquisitionAuctionCleanPrice']==np.inf, np.nan, df['MMRAcquisitionAuctionCleanPrice'])
df['MMRAcquisitionRetailAveragePrice'] = np.where(df['MMRAcquisitionRetailAveragePrice']==np.inf, np.nan, df['MMRAcquisitionRetailAveragePrice'])
df['MMRAcquisitonRetailCleanPrice'] = np.where(df['MMRAcquisitonRetailCleanPrice']==np.inf, np.nan, df['MMRAcquisitonRetailCleanPrice'])
df['MMRCurrentAuctionAveragePrice'] = np.where(df['MMRCurrentAuctionAveragePrice']==np.inf, np.nan, df['MMRCurrentAuctionAveragePrice'])
df['MMRCurrentAuctionCleanPrice'] = np.where(df['MMRCurrentAuctionCleanPrice']==np.inf, np.nan, df['MMRCurrentAuctionCleanPrice'])
df['MMRCurrentRetailAveragePrice'] = np.where(df['MMRCurrentRetailAveragePrice']==np.inf, np.nan, df['MMRCurrentRetailAveragePrice'])
df['MMRCurrentRetailCleanPrice'] = np.where(df['MMRCurrentRetailCleanPrice']==np.inf, np.nan, df['MMRCurrentRetailCleanPrice'])
df['WarrantyCost'] = np.where(df['WarrantyCost']==np.inf, np.nan, df['WarrantyCost'])

df['MMRAcquisitionAuctionAveragePrice'] = df['MMRAcquisitionAuctionAveragePrice'].fillna(df['MMRAcquisitionAuctionAveragePrice'].mean())
df['MMRAcquisitionAuctionCleanPrice'] = df['MMRAcquisitionAuctionCleanPrice'].fillna(df['MMRAcquisitionAuctionCleanPrice'].mean())
df['MMRAcquisitionRetailAveragePrice'] = df['MMRAcquisitionRetailAveragePrice'].fillna(df['MMRAcquisitionRetailAveragePrice'].mean())
df['MMRAcquisitonRetailCleanPrice'] = df['MMRAcquisitonRetailCleanPrice'].fillna(df['MMRAcquisitonRetailCleanPrice'].mean())
df['MMRCurrentAuctionAveragePrice'] = df['MMRCurrentAuctionAveragePrice'].fillna(df['MMRCurrentAuctionAveragePrice'].mean())
df['MMRCurrentAuctionCleanPrice'] = df['MMRCurrentAuctionCleanPrice'].fillna(df['MMRCurrentAuctionCleanPrice'].mean())
df['MMRCurrentRetailAveragePrice'] = df['MMRCurrentRetailAveragePrice'].fillna(df['MMRCurrentRetailAveragePrice'].mean())
df['MMRCurrentRetailCleanPrice'] = df['MMRCurrentRetailCleanPrice'].fillna(df['MMRCurrentRetailCleanPrice'].mean())
df['WarrantyCost'] = df['WarrantyCost'].fillna(df['WarrantyCost'].mean())

df['VehicleAge_decades'] = df['VehicleAge']/10
df['VehOdo_lakhs'] = df['VehOdo']/100000
df.shape
# Out:
# (195, 23)

# %% [markdown]
# ### 4. creating columns - categorical
# * converting categorical to numerical - Make, Transmission, WheelType, Nationality, Size, PRIMEUNIT, AUCGUART, VNST
# * all are positively related - this is based on the imputation

# %%
df['Make'] = np.where(df['Make'].isin(['FORD','PONTIAC','SATURN']), 1, 
                      np.where(df['Make'].isin(['DODGE']), -1, 0))
df['Transmission'] = np.where(df['Transmission']=='AUTO', 1, -1)
df['WheelType'] = np.where(df['WheelType'].isnull(), 1, -1)
df['Nationality'] = np.where(df['Nationality']=='TOP LINE ASIAN', 1, -1)
df['Size'] = np.where(df['Size'].isin(['MEDIUM','COMPACT','LARGE','VAN']), 0, 
                      np.where(df['Size'].isin(['MEDIUM SUV']), 1, -1))
df['PRIMEUNIT'] = np.where(df['PRIMEUNIT'].isnull(), 1, -1)
df['VNST'] = np.where(df['VNST']=='VA', 1, -1)
df.shape
# Out:
# (195, 23)

# %% [markdown]
# ### 5. exporting dataset
# * there are 11 numerical variables
# * there are 7 categorical variables
# * there are 2 other variables - RefId and IsBadBuy
# * also looking at univariate

# %%
df = df.drop(['VehicleAge','VehOdo','VehBCost'], axis=1)
df.to_csv('01 data prep.csv', index=False)
df.shape
# Out:
# (195, 20)

# %%
df.describe(include='all').T
# Out:
#                                    count        mean         std        min  \
# RefId                              195.0  250.548718  141.320070  16.000000
# IsBadBuy                           195.0    0.312821    0.464835   0.000000
# Make                               195.0    0.148718    0.628725  -1.000000
# Transmission                       195.0    0.856410    0.517625  -1.000000
# WheelType                          195.0   -0.794872    0.608339  -1.000000
# Nationality                        195.0   -0.897436    0.442280  -1.000000
# Size                               195.0   -0.102564    0.555890  -1.000000
# MMRAcquisitionAuctionAveragePrice  195.0    1.246107    0.312993   0.751520
# MMRAcquisitionAuctionCleanPrice    195.0    1.001423    0.204953   0.646927
# MMRAcquisitionRetailAveragePrice   195.0    0.776741    0.161716   0.516369
# MMRAcquisitonRetailCleanPrice      195.0    0.661019    0.121975   0.424541
# MMRCurrentAuctionAveragePrice      195.0    1.241328    0.298821   0.657063
# MMRCurrentAuctionCleanPrice        195.0    0.993906    0.197582   0.531661
# MMRCurrentRetailAveragePrice       195.0    0.774785    0.145580   0.488752
# MMRCurrentRetailCleanPrice         195.0    0.662040    0.109180   0.414563
# PRIMEUNIT                          195.0    0.835897    0.550299  -1.000000
# VNST                               195.0   -0.692308    0.723460  -1.000000
# WarrantyCost                       195.0    0.212979    0.146762   0.063317
# VehicleAge_decades                 195.0    0.495385    0.178566   0.100000
# VehOdo_lakhs                       195.0    0.705617    0.135117   0.326710
#
#                                           25%         50%         75%  \
# RefId                              128.500000  253.000000  374.500000
# IsBadBuy                             0.000000    0.000000    1.000000
# Make                                 0.000000    0.000000    1.000000
# Transmission                         1.000000    1.000000    1.000000
# WheelType                           -1.000000   -1.000000   -1.000000
# Nationality                         -1.000000   -1.000000   -1.000000
# Size                                 0.000000    0.000000    0.000000
# MMRAcquisitionAuctionAveragePrice    1.011608    1.205597    1.422451
# MMRAcquisitionAuctionCleanPrice      0.837864    0.975627    1.128049
# MMRAcquisitionRetailAveragePrice     0.663671    0.756496    0.855805
# MMRAcquisitonRetailCleanPrice        0.580752    0.643627    0.726166
# MMRCurrentAuctionAveragePrice        1.021956    1.190041    1.421464
# MMRCurrentAuctionCleanPrice          0.846918    0.975491    1.117095
# MMRCurrentRetailAveragePrice         0.680535    0.761968    0.842814
# MMRCurrentRetailCleanPrice           0.594000    0.648253    0.712103
# PRIMEUNIT                            1.000000    1.000000    1.000000
# VNST                                -1.000000   -1.000000   -1.000000
# WarrantyCost                         0.126252    0.171625    0.263375
# VehicleAge_decades                   0.400000    0.500000    0.600000
# VehOdo_lakhs                         0.611325    0.714230    0.806595
#
#                                           max
# RefId                              481.000000
# IsBadBuy                             1.000000
# Make                                 1.000000
# Transmission                         1.000000
# WheelType                            1.000000
# Nationality                          1.000000
# Size                                 1.000000
# MMRAcquisitionAuctionAveragePrice    2.516779
# MMRAcquisitionAuctionCleanPrice      1.647954
# MMRAcquisitionRetailAveragePrice     1.404270
# MMRAcquisitonRetailCleanPrice        1.112867
# MMRCurrentAuctionAveragePrice        2.460361
# MMRCurrentAuctionCleanPrice          1.587862
# MMRCurrentRetailAveragePrice         1.331971
# MMRCurrentRetailCleanPrice           1.085917
# PRIMEUNIT                            1.000000
# VNST                                 1.000000
# WarrantyCost                         1.242898
# VehicleAge_decades                   0.900000
# VehOdo_lakhs                         0.983580

# %%
df.drop('RefId', axis=1).corr()
# Out:
#                                    IsBadBuy      Make  Transmission  \
# IsBadBuy                           1.000000  0.228022      0.187645
# Make                               0.228022  1.000000     -0.187467
# Transmission                       0.187645 -0.187467      1.000000
# WheelType                          0.464596  0.054599      0.094020
# Nationality                        0.043717 -0.055136      0.064660
# Size                               0.104857 -0.029875      0.020211
# MMRAcquisitionAuctionAveragePrice  0.076250  0.077252     -0.079798
# MMRAcquisitionAuctionCleanPrice    0.055340  0.051625     -0.060547
# MMRAcquisitionRetailAveragePrice   0.202481 -0.039140      0.035218
# MMRAcquisitonRetailCleanPrice      0.176905 -0.077145      0.064300
# MMRCurrentAuctionAveragePrice      0.033969  0.074869     -0.075611
# MMRCurrentAuctionCleanPrice        0.008425  0.050598     -0.061242
# MMRCurrentRetailAveragePrice       0.178147 -0.032803      0.087562
# MMRCurrentRetailCleanPrice         0.121945 -0.057658      0.098185
# PRIMEUNIT                          0.161416  0.100698     -0.083149
# VNST                               0.264113 -0.055790      0.063530
# WarrantyCost                       0.093795  0.097128      0.018193
# VehicleAge_decades                 0.185157  0.208164     -0.040668
# VehOdo_lakhs                       0.061162  0.110047      0.005132
#
#                                    WheelType  Nationality      Size  \
# IsBadBuy                            0.464596     0.043717  0.104857
# Make                                0.054599    -0.055136 -0.029875
# Transmission                        0.094020     0.064660  0.020211
# WheelType                           1.000000     0.151301  0.062534
# Nationality                         0.151301     1.000000  0.084938
# Size                                0.062534     0.084938  1.000000
# MMRAcquisitionAuctionAveragePrice  -0.050222    -0.012597  0.016773
# MMRAcquisitionAuctionCleanPrice    -0.062474     0.026484 -0.019343
# MMRAcquisitionRetailAveragePrice    0.116064     0.008320  0.016703
# MMRAcquisitonRetailCleanPrice       0.089371     0.020578  0.022765
# MMRCurrentAuctionAveragePrice      -0.037156    -0.044319  0.110201
# MMRCurrentAuctionCleanPrice        -0.044596    -0.009258  0.067442
# MMRCurrentRetailAveragePrice        0.131731    -0.007187  0.061186
# MMRCurrentRetailCleanPrice          0.078998     0.002607  0.027564
# PRIMEUNIT                           0.101072    -0.015205 -0.156407
# VNST                                0.183791    -0.034698  0.078875
# WarrantyCost                       -0.068868    -0.165877  0.181911
# VehicleAge_decades                  0.075193     0.097400 -0.015179
# VehOdo_lakhs                        0.042646     0.070197  0.035328
#
#                                    MMRAcquisitionAuctionAveragePrice  \
# IsBadBuy                                                    0.076250
# Make                                                        0.077252
# Transmission                                               -0.079798
# WheelType                                                  -0.050222
# Nationality                                                -0.012597
# Size                                                        0.016773
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.965074
# MMRAcquisitionRetailAveragePrice                            0.621714
# MMRAcquisitonRetailCleanPrice                               0.567897
# MMRCurrentAuctionAveragePrice                               0.811703
# MMRCurrentAuctionCleanPrice                                 0.779849
# MMRCurrentRetailAveragePrice                                0.520665
# MMRCurrentRetailCleanPrice                                  0.495718
# PRIMEUNIT                                                  -0.109826
# VNST                                                       -0.066493
# WarrantyCost                                                0.288463
# VehicleAge_decades                                          0.713065
# VehOdo_lakhs                                               -0.012699
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# IsBadBuy                                                  0.055340
# Make                                                      0.051625
# Transmission                                             -0.060547
# WheelType                                                -0.062474
# Nationality                                               0.026484
# Size                                                     -0.019343
# MMRAcquisitionAuctionAveragePrice                         0.965074
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.630122
# MMRAcquisitonRetailCleanPrice                             0.627431
# MMRCurrentAuctionAveragePrice                             0.770470
# MMRCurrentAuctionCleanPrice                               0.784028
# MMRCurrentRetailAveragePrice                              0.524392
# MMRCurrentRetailCleanPrice                                0.531132
# PRIMEUNIT                                                -0.122149
# VNST                                                     -0.114179
# WarrantyCost                                              0.193390
# VehicleAge_decades                                        0.668135
# VehOdo_lakhs                                             -0.066893
#
#                                    MMRAcquisitionRetailAveragePrice  \
# IsBadBuy                                                   0.202481
# Make                                                      -0.039140
# Transmission                                               0.035218
# WheelType                                                  0.116064
# Nationality                                                0.008320
# Size                                                       0.016703
# MMRAcquisitionAuctionAveragePrice                          0.621714
# MMRAcquisitionAuctionCleanPrice                            0.630122
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.964086
# MMRCurrentAuctionAveragePrice                              0.516961
# MMRCurrentAuctionCleanPrice                                0.531651
# MMRCurrentRetailAveragePrice                               0.873097
# MMRCurrentRetailCleanPrice                                 0.852501
# PRIMEUNIT                                                  0.007992
# VNST                                                       0.561585
# WarrantyCost                                               0.121564
# VehicleAge_decades                                         0.386631
# VehOdo_lakhs                                              -0.122051
#
#                                    MMRAcquisitonRetailCleanPrice  \
# IsBadBuy                                                0.176905
# Make                                                   -0.077145
# Transmission                                            0.064300
# WheelType                                               0.089371
# Nationality                                             0.020578
# Size                                                    0.022765
# MMRAcquisitionAuctionAveragePrice                       0.567897
# MMRAcquisitionAuctionCleanPrice                         0.627431
# MMRAcquisitionRetailAveragePrice                        0.964086
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.454126
# MMRCurrentAuctionCleanPrice                             0.503962
# MMRCurrentRetailAveragePrice                            0.832747
# MMRCurrentRetailCleanPrice                              0.849408
# PRIMEUNIT                                              -0.011028
# VNST                                                    0.495682
# WarrantyCost                                            0.032320
# VehicleAge_decades                                      0.308321
# VehOdo_lakhs                                           -0.180240
#
#                                    MMRCurrentAuctionAveragePrice  \
# IsBadBuy                                                0.033969
# Make                                                    0.074869
# Transmission                                           -0.075611
# WheelType                                              -0.037156
# Nationality                                            -0.044319
# Size                                                    0.110201
# MMRAcquisitionAuctionAveragePrice                       0.811703
# MMRAcquisitionAuctionCleanPrice                         0.770470
# MMRAcquisitionRetailAveragePrice                        0.516961
# MMRAcquisitonRetailCleanPrice                           0.454126
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.965534
# MMRCurrentRetailAveragePrice                            0.598774
# MMRCurrentRetailCleanPrice                              0.570768
# PRIMEUNIT                                              -0.001303
# VNST                                                   -0.040523
# WarrantyCost                                            0.310180
# VehicleAge_decades                                      0.675902
# VehOdo_lakhs                                           -0.010722
#
#                                    MMRCurrentAuctionCleanPrice  \
# IsBadBuy                                              0.008425
# Make                                                  0.050598
# Transmission                                         -0.061242
# WheelType                                            -0.044596
# Nationality                                          -0.009258
# Size                                                  0.067442
# MMRAcquisitionAuctionAveragePrice                     0.779849
# MMRAcquisitionAuctionCleanPrice                       0.784028
# MMRAcquisitionRetailAveragePrice                      0.531651
# MMRAcquisitonRetailCleanPrice                         0.503962
# MMRCurrentAuctionAveragePrice                         0.965534
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.609911
# MMRCurrentRetailCleanPrice                            0.633818
# PRIMEUNIT                                             0.011054
# VNST                                                 -0.074482
# WarrantyCost                                          0.210548
# VehicleAge_decades                                    0.626584
# VehOdo_lakhs                                         -0.062207
#
#                                    MMRCurrentRetailAveragePrice  \
# IsBadBuy                                               0.178147
# Make                                                  -0.032803
# Transmission                                           0.087562
# WheelType                                              0.131731
# Nationality                                           -0.007187
# Size                                                   0.061186
# MMRAcquisitionAuctionAveragePrice                      0.520665
# MMRAcquisitionAuctionCleanPrice                        0.524392
# MMRAcquisitionRetailAveragePrice                       0.873097
# MMRAcquisitonRetailCleanPrice                          0.832747
# MMRCurrentAuctionAveragePrice                          0.598774
# MMRCurrentAuctionCleanPrice                            0.609911
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.960742
# PRIMEUNIT                                              0.026640
# VNST                                                   0.555235
# WarrantyCost                                           0.155404
# VehicleAge_decades                                     0.365265
# VehOdo_lakhs                                          -0.115093
#
#                                    MMRCurrentRetailCleanPrice  PRIMEUNIT  \
# IsBadBuy                                             0.121945   0.161416
# Make                                                -0.057658   0.100698
# Transmission                                         0.098185  -0.083149
# WheelType                                            0.078998   0.101072
# Nationality                                          0.002607  -0.015205
# Size                                                 0.027564  -0.156407
# MMRAcquisitionAuctionAveragePrice                    0.495718  -0.109826
# MMRAcquisitionAuctionCleanPrice                      0.531132  -0.122149
# MMRAcquisitionRetailAveragePrice                     0.852501   0.007992
# MMRAcquisitonRetailCleanPrice                        0.849408  -0.011028
# MMRCurrentAuctionAveragePrice                        0.570768  -0.001303
# MMRCurrentAuctionCleanPrice                          0.633818   0.011054
# MMRCurrentRetailAveragePrice                         0.960742   0.026640
# MMRCurrentRetailCleanPrice                           1.000000   0.029818
# PRIMEUNIT                                            0.029818   1.000000
# VNST                                                 0.485719   0.127483
# WarrantyCost                                         0.073941   0.025591
# VehicleAge_decades                                   0.318194   0.034218
# VehOdo_lakhs                                        -0.161608   0.056117
#
#                                        VNST  WarrantyCost  VehicleAge_decades  \
# IsBadBuy                           0.264113      0.093795            0.185157
# Make                              -0.055790      0.097128            0.208164
# Transmission                       0.063530      0.018193           -0.040668
# WheelType                          0.183791     -0.068868            0.075193
# Nationality                       -0.034698     -0.165877            0.097400
# Size                               0.078875      0.181911           -0.015179
# MMRAcquisitionAuctionAveragePrice -0.066493      0.288463            0.713065
# MMRAcquisitionAuctionCleanPrice   -0.114179      0.193390            0.668135
# MMRAcquisitionRetailAveragePrice   0.561585      0.121564            0.386631
# MMRAcquisitonRetailCleanPrice      0.495682      0.032320            0.308321
# MMRCurrentAuctionAveragePrice     -0.040523      0.310180            0.675902
# MMRCurrentAuctionCleanPrice       -0.074482      0.210548            0.626584
# MMRCurrentRetailAveragePrice       0.555235      0.155404            0.365265
# MMRCurrentRetailCleanPrice         0.485719      0.073941            0.318194
# PRIMEUNIT                          0.127483      0.025591            0.034218
# VNST                               1.000000      0.179932           -0.148555
# WarrantyCost                       0.179932      1.000000            0.402994
# VehicleAge_decades                -0.148555      0.402994            1.000000
# VehOdo_lakhs                      -0.019990      0.394694            0.274626
#
#                                    VehOdo_lakhs
# IsBadBuy                               0.061162
# Make                                   0.110047
# Transmission                           0.005132
# WheelType                              0.042646
# Nationality                            0.070197
# Size                                   0.035328
# MMRAcquisitionAuctionAveragePrice     -0.012699
# MMRAcquisitionAuctionCleanPrice       -0.066893
# MMRAcquisitionRetailAveragePrice      -0.122051
# MMRAcquisitonRetailCleanPrice         -0.180240
# MMRCurrentAuctionAveragePrice         -0.010722
# MMRCurrentAuctionCleanPrice           -0.062207
# MMRCurrentRetailAveragePrice          -0.115093
# MMRCurrentRetailCleanPrice            -0.161608
# PRIMEUNIT                              0.056117
# VNST                                  -0.019990
# WarrantyCost                           0.394694
# VehicleAge_decades                     0.274626
# VehOdo_lakhs                           1.000000
